# %%
from torchvision.models.vgg import vgg13

# %%
vggNet=vgg13(pretrained=True)

# %%
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img=io.imread('demo_3.jpg')

# %%
fig=plt.figure(figsize=(7,13))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 2136.5, 3263.5, -0.5)

# %%
import torch
import torchvision.transforms as T
print(img.shape)
trsfm=T.ToTensor()
img1=io.imread('demo_3.jpg')
img2=io.imread('demo_4.jpg')



img=np.array((img1,img2))
x=trsfm(img1).unsqueeze(0)
print(x.shape)
# y=vggNet(x)
# Out:
# (3264, 2137, 3)
# torch.Size([1, 3, 3264, 2137])
